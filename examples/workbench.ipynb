# %%
from cadetgui.widgets.composite import WorkbenchWidget

workbench = WorkbenchWidget()
workbench.display()
# Out:
# /home/IBT/lanzrath/CADET/CADET-Process/CADETProcess/modelBuilder/batchElutionBuilder.py:62: UserWarning: Renaming column to `column` for consistency
#   warnings.warn("Renaming column to `column` for consistency")
# ...
